# %%
#Nom d'utisateur
prenom= "Amar"
nom= "kebe"
print(nom,prenom)
# Out:
# kebe Amar

# %%
#valeur de echantillon 5
n=5
print(5+55+555)
# Out:
# 615

# %%
#pair impair
if n//2:
    print("pair")
n=3
print("n")
# Out:
# pair

# %%
if n//3:
    print("impair")
# Out:
# impair

# %%
for i in range(2000,3200):
    print(i/7,i+5)
# Out:
# 285.7142857142857 2005
# 285.85714285714283 2006
# 286.0 2007
# 286.14285714285717 2008
# 286.2857142857143 2009
# 286.42857142857144 2010
# 286.57142857142856 2011
# 286.7142857142857 2012
# 286.85714285714283 2013
# 287.0 2014
# 287.14285714285717 2015
# 287.2857142857143 2016
# 287.42857142857144 2017
# 287.57142857142856 2018
# 287.7142857142857 2019
# 287.85714285714283 2020
# 288.0 2021
# 288.14285714285717 2022
# 288.2857142857143 2023
# 288.42857142857144 2024
# 288.57142857142856 2025
# 288.7142857142857 2026
# 288.85714285714283 2027
# 289.0 2028
# 289.14285714285717 2029
# 289.2857142857143 2030
# 289.42857142857144 2031
# 289.57142857142856 2032
# 289.7142857142857 2033
# 289.85714285714283 2034
# 290.0 2035
# 290.14285714285717 2036
# 290.2857142857143 2037
# 290.42857142857144 2038
# 290.57142857142856 2039
# 290.7142857142857 2040
# 290.85714285714283 2041
# 291.0 2042
# 291.14285714285717 2043
# 291.2857142857143 2044
# 291.42857142857144 2045
# ...

# %%
# coding utf-8
facto= 1
n=int(input("Tapez la valeur de n:"))
for i in range(1,n+1):
    facto=facto*i
print("Factorielle de n est :",facto)
# Out:
# Tapez la valeur de n: 8
# Factorielle de n est : 40320

# %%
#Écrivez un programme pour supprimer les caractères qui ont des valeurs d'index impaires d'une chaîne donnée.
def delete_char(string, n):
    string1=""
    for i in range(0,n):
        if (i%2==0):
            string1= string1 + string[i]
    return string1
string1="hello team"
print(delete_char(string,9))
# Out:
# hlota

# %%
valeur=int(input("Entrez le prix:,"))
if valeur>=500:
    prix=valeur-(50/100)*valeur
elif valeur>=200>=500:
    prix=valeur-30/100*valeur
else :
    valeur<200
    prix=valeur-10/100*valeur
    
print("Afficher le prix est",prix,)
# Out:
# Entrez le prix:, 350
# Afficher le prix est 315.0
